# %% [markdown]
# This project's main goal was to utilize a CNN based model to analyze song audio files converted to mel spectrograms and see if it could classify/predict the album the song was released on with reasonable accuracy. I focused on a single artist "Green Day" and 7 albums to build a framework I intend to build upon over time. Green day was used since I already had the audiofiles accessable.
#
# The first step involved generating enough data to train a CNN model.  I decided to split the songs into 15 segments per song. 10 of those segments were used for the initial train and test set. the other 5 were set aside to further evaluate the model once it was saved and reloaded.
#
# A potential issue in generating the data was how the songs were split into 15 equal segments. The impact of song length on model performance was not fully explored or corrected. This will be investigated more in the future. However, its worth noting that song length did seem to have an impact as the album American Idiot has 2 unusually long songs. when initial testing the model including american idiot in the test data produced much lower accuracy after traing than when it was left out. as a quick fix, Jesus of Suburbia was split into 5 parts since it was written with 5 distinct and subtitled section in the song. Homecoming was removed as an outlier due to its length and the song section being written and sung by each member of the group. however a more robust method of splitting songs into multiple parts needs to be developed.
#
# Features and labels were extracted from the song segments during the conversion to mel spectrograms. the data was preprocesed to a usable structure the CNN could interpret. A confusion matrix, accuracy plot over epochs, and accuracy calculation were generated after traning the model. the model was save and reloaded and 5 new song segments were preprocessed in the same manner as the training/test data and the model correctly predicted the album labels for the song segment with a 78% success rate.
#
# This model was an exercise and more work can be done to improve performance and capabilities which I will implement over time.

# %%
import os
from pydub import AudioSegment
from pydub.exceptions import CouldntDecodeError

# Function to split an audio file into 15 segments and distribute them between training and evaluation folders
def split_audio(file_path, train_folder, eval_folder):
    # Get base name and extension of file
    file_name, file_extension = os.path.splitext(os.path.basename(file_path))

    try:
        # Load audio file with format explicitly specified
        audio = AudioSegment.from_file(file_path, format=file_extension[1:])
        
        # Calculate segment duration
        segment_duration = len(audio) // 15  # Divide into 15 segments.placing 5 segements in separate folder to test model after training/saving
        
        # Create output folders if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(eval_folder, exist_ok=True)
        
        # Split and export segments: first 10 for training, last 5 for evaluation
        for i in range(15):
            start_time = i * segment_duration
            end_time = start_time + segment_duration
            
            # Export segment with the same file extension
            segment = audio[start_time:end_time]
            
            if i < 10:
                # Save first 10 segments to the training folder
                output_file = os.path.join(train_folder, f"{file_name}_segment_{i+1}{file_extension}")
            else:
                # Save last 5 segments to the evaluation folder
                output_file = os.path.join(eval_folder, f"{file_name}_segment_{i+1}{file_extension}")
                
            segment.export(output_file, format=file_extension[1:])  # Remove the dot from the extension
            print(f"Exported {output_file}")
    except CouldntDecodeError:
        print(f"Could not decode {file_path}, skipping file.")

# Base directory containing subfolders with audio files
base_dir = 'C://Users/morni/Side Projects/Green Day'

# Define the output directories inside the base directory
train_folder = os.path.join(base_dir, 'output_segments', 'train')
eval_folder = os.path.join(base_dir, 'output_segments', 'eval')

# Walk through all subdirectories in the base directory, skipping 'output_segments'
for root, dirs, files in os.walk(base_dir):
    # Skip processing the 'output_segments' folder
    dirs[:] = [d for d in dirs if d != 'output_segments']
    
    for file in files:
        if file.endswith('.mp3') or file.endswith('.wav'):  # Adjust for more formats if needed
            # Get the full path of the audio file
            file_path = os.path.join(root, file)
            
            # Create an output folder for each subfolder for both training and evaluation
            relative_path = os.path.relpath(root, base_dir)
            subfolder_train = os.path.join(train_folder, relative_path)
            subfolder_eval = os.path.join(eval_folder, relative_path)
            
            # Split the audio file and save the segments
            split_audio(file_path, subfolder_train, subfolder_eval)

# %%
import os
import librosa
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models

# Initialize lists to store features and labels
features = []
labels = []

base_dir = base_dir = 'C://Users/morni/Side Projects/Green Day/output_segments/train'

# Function to extract mel spectrogram and MFCC from audio file
def extract_features(file, max_len=128, n_mfcc=13, hop_length=1024):
    y, sr = librosa.load(file, sr=22050)
    
    # Extract Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=hop_length)
    mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
    
    # Extract MFCC using the same hop length
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
    
    # Ensure all features have the same length
    if mel_spect_db.shape[1] > max_len:
        mel_spect_db = mel_spect_db[:, :max_len]
    else:
        pad_width = max_len - mel_spect_db.shape[1]
        mel_spect_db = np.pad(mel_spect_db, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    if mfccs.shape[1] > max_len:
        mfccs = mfccs[:, :max_len]
    else:
        pad_width = max_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    
    # Concatenate Mel spectrogram and MFCCs along the first axis
    combined_features = np.concatenate((mel_spect_db, mfccs), axis=0)
    
    return combined_features

# Loop through each folder in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    if os.path.isdir(folder_path):
        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.mp3'):
                file_path = os.path.join(folder_path, file_name)
                
                # Extract combined features (Mel spectrogram + MFCCs)
                combined_features = extract_features(file_path)
                features.append(combined_features)
                
                # Add the label (first letter of folder name as label capitalized)
                labels.append(folder_name[0].upper())

# Convert to numpy arrays
X = np.array(features)
y = np.array(labels)

# Encode the labels
unique_labels = np.unique(y)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_encoded = np.array([label_map[label] for label in y])
y_encoded = to_categorical(y_encoded, num_classes=len(unique_labels))

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=442)

# Add a channel dimension for CNN
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Add an Input layer
model = models.Sequential()
model.add(layers.Input(shape=(141, 128, 1)))  # Specify input shape (141 = 128 Mel bands + 13 MFCCs)

# First Conv Layer
model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Second Conv Layer
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# third Conv Layer
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Flatten and add Dense layers
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.3))  # Prevent overfitting
model.add(layers.Dense(len(unique_labels), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc}")

# Predict the labels for the test set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plotting accuracy over epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 380ms/step - accuracy: 0.1297 - loss: 6.2303 - val_accuracy: 0.2092 - val_loss: 1.8180
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 386ms/step - accuracy: 0.2531 - loss: 1.7828 - val_accuracy: 0.3214 - val_loss: 1.7322
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 381ms/step - accuracy: 0.3841 - loss: 1.6552 - val_accuracy: 0.5408 - val_loss: 1.4690
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 408ms/step - accuracy: 0.4158 - loss: 1.5101 - val_accuracy: 0.5051 - val_loss: 1.3179
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 404ms/step - accuracy: 0.5595 - loss: 1.2860 - val_accuracy: 0.5969 - val_loss: 1.2686
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 390ms/step - accuracy: 0.5691 - loss: 1.1883 - val_accuracy: 0.6684 - val_loss: 0.9256
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step - accuracy: 0.7066 - loss: 0.8446 - val_accuracy: 0.5867 - val_loss: 1.0319
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 398ms/step - accuracy: 0.7180 - loss: 0.7775 - val_accuracy: 0.7296 - val_loss: 0.7592
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 401ms/step - accuracy: 0.7909 - loss: 0.6271 - val_accuracy: 0.4592 - val_loss: 1.3978
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - accuracy: 0.5999 - loss: 1.1251 - val_accuracy: 0.7500 - val_loss: 0.6730
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 391ms/step - accuracy: 0.8061 - loss: 0.5627 - val_accuracy: 0.6684 - val_loss: 0.9676
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 401ms/step - accuracy: 0.7928 - loss: 0.5973 - val_accuracy: 0.7602 - val_loss: 0.8518
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 400ms/step - accuracy: 0.7752 - loss: 0.6104 - val_accuracy: 0.7857 - val_loss: 0.6485
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 398ms/step - accuracy: 0.7999 - loss: 0.5265 - val_accuracy: 0.7296 - val_loss: 0.8299
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - accuracy: 0.8110 - loss: 0.5550 - val_accuracy: 0.7296 - val_loss: 0.7263
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 398ms/step - accuracy: 0.8421 - loss: 0.4407 - val_accuracy: 0.7296 - val_loss: 0.7909
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 419ms/step - accuracy: 0.8630 - loss: 0.3964 - val_accuracy: 0.7806 - val_loss: 0.7562
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 421ms/step - accuracy: 0.8689 - loss: 0.3397 - val_accuracy: 0.7551 - val_loss: 0.7837
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 413ms/step - accuracy: 0.8689 - loss: 0.3216 - val_accuracy: 0.7602 - val_loss: 0.8172
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 427ms/step - accuracy: 0.8831 - loss: 0.3736 - val_accuracy: 0.8163 - val_loss: 0.7733
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 428ms/step - accuracy: 0.8933 - loss: 0.2693 - val_accuracy: 0.7602 - val_loss: 0.9444
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - accuracy: 0.9091 - loss: 0.2297 - val_accuracy: 0.7908 - val_loss: 0.8223
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 426ms/step - accuracy: 0.9344 - loss: 0.2238 - val_accuracy: 0.8112 - val_loss: 0.8190
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 430ms/step - accuracy: 0.9560 - loss: 0.1446 - val_accuracy: 0.8061 - val_loss: 0.8518
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 419ms/step - accuracy: 0.9640 - loss: 0.1057 - val_accuracy: 0.7653 - val_loss: 1.1059
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 432ms/step - accuracy: 0.8639 - loss: 0.3412 - val_accuracy: 0.7806 - val_loss: 0.8103
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 434ms/step - accuracy: 0.8928 - loss: 0.2770 - val_accuracy: 0.7449 - val_loss: 0.9643
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 419ms/step - accuracy: 0.9107 - loss: 0.2483 - val_accuracy: 0.7602 - val_loss: 0.9176
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 432ms/step - accuracy: 0.9305 - loss: 0.2150 - val_accuracy: 0.7449 - val_loss: 1.0209
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 434ms/step - accuracy: 0.9554 - loss: 0.1399 - val_accuracy: 0.7857 - val_loss: 1.0537
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.8122 - loss: 0.8294
# Test Accuracy: 0.7857142686843872
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step

# %%
model.save('C://Users/morni/Side Projects/Green Day/GD_Class_mdl2.keras')

# %%
import os
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models

# Initialize lists to store features and labels
features = []
labels = []

# Define base directory where your .wav files are located
base_dir = 'C://Users/morni/Side Projects/Green Day/output_segments/eval'

# Function to extract mel spectrogram and MFCC from audio file
def extract_features(file, max_len=128, n_mfcc=13, hop_length=1024):
    y, sr = librosa.load(file, sr=22050)
    
    # Extract Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=hop_length)
    mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
    
    # Extract MFCC using the same hop length
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
    
    # Ensure all features have the same length
    if mel_spect_db.shape[1] > max_len:
        mel_spect_db = mel_spect_db[:, :max_len]
    else:
        pad_width = max_len - mel_spect_db.shape[1]
        mel_spect_db = np.pad(mel_spect_db, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    if mfccs.shape[1] > max_len:
        mfccs = mfccs[:, :max_len]
    else:
        pad_width = max_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    
    # Concatenate Mel spectrogram and MFCCs along the first axis
    features = np.concatenate((mel_spect_db, mfccs), axis=0)
    
    return features

# Loop through each folder in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    if os.path.isdir(folder_path):
        # Assign the folder name (or some characteristic) as the label
        label = folder_name[0].upper()  # E.g., first letter of folder name as label
        
        # Loop through each file in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.mp3'):
                file_path = os.path.join(folder_path, file_name)
                
                # Extract combined features (Mel spectrogram + MFCCs)
                combined_features = extract_features(file_path)
                features.append(combined_features)
                
                # Append the corresponding label for each file
                labels.append(label)

# Convert to numpy arrays
X = np.array(features)
y = np.array(labels)

# Encode the labels
unique_labels = np.unique(y)
label_map = {label: i for i, label in enumerate(unique_labels)}
y_encoded = np.array([label_map[label] for label in y])
y_encoded = to_categorical(y_encoded, num_classes=len(unique_labels))

# Add a channel dimension to the features for CNN input (batch, height, width, channel)
X = X[..., np.newaxis]

# Load the saved model
loaded_model = tf.keras.models.load_model('C://Users/morni/Side Projects/Green Day/GD_Class_mdl2.keras')

# Use the model to predict
predictions = loaded_model.predict(X)

# Get the predicted class labels
predicted_classes = np.argmax(predictions, axis=1)

# Map predicted class indices back to original labels
predicted_labels = [unique_labels[i] for i in predicted_classes]

# Initialize a counter for correct predictions
correct_predictions = 0

# Print the actual labels and the predicted labels
for i, predicted_label in enumerate(predicted_labels):
    actual_label = y[i]  # Get the actual label from the original labels array
    print(f"Sample {i}: Actual label: {actual_label}, Predicted label: {predicted_label}")
    
    # Check if the prediction is correct
    if predicted_label == actual_label:
        correct_predictions += 1

# Calculate percent accuracy
total_samples = len(predicted_labels)
accuracy = (correct_predictions / total_samples) * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
# Sample 0: Actual label: A, Predicted label: A
# Sample 1: Actual label: A, Predicted label: W
# Sample 2: Actual label: A, Predicted label: A
# Sample 3: Actual label: A, Predicted label: A
# Sample 4: Actual label: A, Predicted label: A
# Sample 5: Actual label: A, Predicted label: A
# Sample 6: Actual label: A, Predicted label: D
# Sample 7: Actual label: A, Predicted label: D
# Sample 8: Actual label: A, Predicted label: A
# Sample 9: Actual label: A, Predicted label: D
# Sample 10: Actual label: A, Predicted label: A
# Sample 11: Actual label: A, Predicted label: A
# Sample 12: Actual label: A, Predicted label: A
# Sample 13: Actual label: A, Predicted label: A
# Sample 14: Actual label: A, Predicted label: A
# Sample 15: Actual label: A, Predicted label: A
# Sample 16: Actual label: A, Predicted label: A
# Sample 17: Actual label: A, Predicted label: A
# Sample 18: Actual label: A, Predicted label: A
# Sample 19: Actual label: A, Predicted label: A
# Sample 20: Actual label: A, Predicted label: A
# Sample 21: Actual label: A, Predicted label: A
# Sample 22: Actual label: A, Predicted label: A
# Sample 23: Actual label: A, Predicted label: A
# Sample 24: Actual label: A, Predicted label: A
# Sample 25: Actual label: A, Predicted label: A
# Sample 26: Actual label: A, Predicted label: A
# Sample 27: Actual label: A, Predicted label: A
# Sample 28: Actual label: A, Predicted label: S
# Sample 29: Actual label: A, Predicted label: W
# Sample 30: Actual label: A, Predicted label: A
# Sample 31: Actual label: A, Predicted label: A
# Sample 32: Actual label: A, Predicted label: A
# Sample 33: Actual label: A, Predicted label: A
# Sample 34: Actual label: A, Predicted label: W
# Sample 35: Actual label: A, Predicted label: A
# Sample 36: Actual label: A, Predicted label: A
# Sample 37: Actual label: A, Predicted label: A
# Sample 38: Actual label: A, Predicted label: A
# Sample 39: Actual label: A, Predicted label: A
# Sample 40: Actual label: A, Predicted label: A
# Sample 41: Actual label: A, Predicted label: A
# Sample 42: Actual label: A, Predicted label: A
# Sample 43: Actual label: A, Predicted label: A
# Sample 44: Actual label: A, Predicted label: D
# Sample 45: Actual label: A, Predicted label: A
# Sample 46: Actual label: A, Predicted label: A
# Sample 47: Actual label: A, Predicted label: A
# Sample 48: Actual label: A, Predicted label: A
# Sample 49: Actual label: A, Predicted label: A
# Sample 50: Actual label: A, Predicted label: A
# Sample 51: Actual label: A, Predicted label: A
# Sample 52: Actual label: A, Predicted label: A
# Sample 53: Actual label: A, Predicted label: A
# Sample 54: Actual label: A, Predicted label: S
# Sample 55: Actual label: A, Predicted label: A
# Sample 56: Actual label: A, Predicted label: A
# Sample 57: Actual label: A, Predicted label: A
# Sample 58: Actual label: A, Predicted label: A
# Sample 59: Actual label: A, Predicted label: A
# Sample 60: Actual label: A, Predicted label: A
# Sample 61: Actual label: A, Predicted label: A
# Sample 62: Actual label: A, Predicted label: A
# Sample 63: Actual label: A, Predicted label: A
# Sample 64: Actual label: A, Predicted label: A
# Sample 65: Actual label: A, Predicted label: A
# Sample 66: Actual label: A, Predicted label: A
# Sample 67: Actual label: A, Predicted label: A
# Sample 68: Actual label: A, Predicted label: A
# Sample 69: Actual label: A, Predicted label: A
# Sample 70: Actual label: A, Predicted label: N
# Sample 71: Actual label: A, Predicted label: I
# Sample 72: Actual label: A, Predicted label: A
# Sample 73: Actual label: A, Predicted label: A
# Sample 74: Actual label: A, Predicted label: N
# Sample 75: Actual label: A, Predicted label: A
# Sample 76: Actual label: A, Predicted label: N
# Sample 77: Actual label: A, Predicted label: A
# Sample 78: Actual label: A, Predicted label: A
# Sample 79: Actual label: A, Predicted label: D
# Sample 80: Actual label: D, Predicted label: D
# Sample 81: Actual label: D, Predicted label: K
# Sample 82: Actual label: D, Predicted label: A
# Sample 83: Actual label: D, Predicted label: A
# Sample 84: Actual label: D, Predicted label: I
# Sample 85: Actual label: D, Predicted label: D
# Sample 86: Actual label: D, Predicted label: D
# Sample 87: Actual label: D, Predicted label: D
# Sample 88: Actual label: D, Predicted label: D
# Sample 89: Actual label: D, Predicted label: D
# Sample 90: Actual label: D, Predicted label: D
# Sample 91: Actual label: D, Predicted label: D
# Sample 92: Actual label: D, Predicted label: D
# Sample 93: Actual label: D, Predicted label: D
# Sample 94: Actual label: D, Predicted label: D
# Sample 95: Actual label: D, Predicted label: D
# Sample 96: Actual label: D, Predicted label: D
# Sample 97: Actual label: D, Predicted label: D
# Sample 98: Actual label: D, Predicted label: A
# Sample 99: Actual label: D, Predicted label: D
# Sample 100: Actual label: D, Predicted label: D
# Sample 101: Actual label: D, Predicted label: D
# Sample 102: Actual label: D, Predicted label: D
# Sample 103: Actual label: D, Predicted label: D
# Sample 104: Actual label: D, Predicted label: A
# Sample 105: Actual label: D, Predicted label: D
# Sample 106: Actual label: D, Predicted label: D
# Sample 107: Actual label: D, Predicted label: D
# Sample 108: Actual label: D, Predicted label: D
# Sample 109: Actual label: D, Predicted label: D
# Sample 110: Actual label: D, Predicted label: D
# Sample 111: Actual label: D, Predicted label: D
# Sample 112: Actual label: D, Predicted label: D
# Sample 113: Actual label: D, Predicted label: D
# Sample 114: Actual label: D, Predicted label: D
# Sample 115: Actual label: D, Predicted label: D
# Sample 116: Actual label: D, Predicted label: D
# Sample 117: Actual label: D, Predicted label: D
# Sample 118: Actual label: D, Predicted label: D
# Sample 119: Actual label: D, Predicted label: D
# Sample 120: Actual label: D, Predicted label: W
# Sample 121: Actual label: D, Predicted label: D
# Sample 122: Actual label: D, Predicted label: D
# Sample 123: Actual label: D, Predicted label: D
# Sample 124: Actual label: D, Predicted label: D
# Sample 125: Actual label: D, Predicted label: D
# Sample 126: Actual label: D, Predicted label: D
# Sample 127: Actual label: D, Predicted label: D
# Sample 128: Actual label: D, Predicted label: D
# Sample 129: Actual label: D, Predicted label: N
# Sample 130: Actual label: D, Predicted label: D
# Sample 131: Actual label: D, Predicted label: D
# Sample 132: Actual label: D, Predicted label: D
# Sample 133: Actual label: D, Predicted label: D
# Sample 134: Actual label: D, Predicted label: D
# Sample 135: Actual label: D, Predicted label: D
# Sample 136: Actual label: D, Predicted label: D
# Sample 137: Actual label: D, Predicted label: D
# Sample 138: Actual label: D, Predicted label: D
# Sample 139: Actual label: D, Predicted label: D
# Sample 140: Actual label: D, Predicted label: D
# Sample 141: Actual label: D, Predicted label: D
# Sample 142: Actual label: D, Predicted label: D
# Sample 143: Actual label: D, Predicted label: D
# Sample 144: Actual label: D, Predicted label: D
# Sample 145: Actual label: D, Predicted label: D
# Sample 146: Actual label: D, Predicted label: A
# Sample 147: Actual label: D, Predicted label: A
# Sample 148: Actual label: D, Predicted label: A
# Sample 149: Actual label: D, Predicted label: A
# Sample 150: Actual label: I, Predicted label: I
# Sample 151: Actual label: I, Predicted label: I
# Sample 152: Actual label: I, Predicted label: I
# Sample 153: Actual label: I, Predicted label: I
# Sample 154: Actual label: I, Predicted label: I
# Sample 155: Actual label: I, Predicted label: I
# Sample 156: Actual label: I, Predicted label: I
# Sample 157: Actual label: I, Predicted label: D
# Sample 158: Actual label: I, Predicted label: D
# Sample 159: Actual label: I, Predicted label: D
# Sample 160: Actual label: I, Predicted label: I
# Sample 161: Actual label: I, Predicted label: I
# Sample 162: Actual label: I, Predicted label: I
# Sample 163: Actual label: I, Predicted label: I
# Sample 164: Actual label: I, Predicted label: D
# Sample 165: Actual label: I, Predicted label: D
# Sample 166: Actual label: I, Predicted label: A
# Sample 167: Actual label: I, Predicted label: I
# Sample 168: Actual label: I, Predicted label: I
# Sample 169: Actual label: I, Predicted label: I
# Sample 170: Actual label: I, Predicted label: S
# Sample 171: Actual label: I, Predicted label: I
# Sample 172: Actual label: I, Predicted label: S
# Sample 173: Actual label: I, Predicted label: I
# Sample 174: Actual label: I, Predicted label: I
# Sample 175: Actual label: I, Predicted label: I
# Sample 176: Actual label: I, Predicted label: I
# Sample 177: Actual label: I, Predicted label: I
# Sample 178: Actual label: I, Predicted label: I
# Sample 179: Actual label: I, Predicted label: I
# Sample 180: Actual label: I, Predicted label: I
# Sample 181: Actual label: I, Predicted label: I
# Sample 182: Actual label: I, Predicted label: I
# Sample 183: Actual label: I, Predicted label: I
# Sample 184: Actual label: I, Predicted label: N
# Sample 185: Actual label: I, Predicted label: I
# Sample 186: Actual label: I, Predicted label: I
# Sample 187: Actual label: I, Predicted label: I
# Sample 188: Actual label: I, Predicted label: I
# Sample 189: Actual label: I, Predicted label: I
# Sample 190: Actual label: I, Predicted label: I
# Sample 191: Actual label: I, Predicted label: I
# Sample 192: Actual label: I, Predicted label: I
# Sample 193: Actual label: I, Predicted label: D
# Sample 194: Actual label: I, Predicted label: I
# Sample 195: Actual label: I, Predicted label: I
# Sample 196: Actual label: I, Predicted label: I
# Sample 197: Actual label: I, Predicted label: I
# Sample 198: Actual label: I, Predicted label: I
# Sample 199: Actual label: I, Predicted label: D
# Sample 200: Actual label: I, Predicted label: I
# Sample 201: Actual label: I, Predicted label: I
# Sample 202: Actual label: I, Predicted label: I
# Sample 203: Actual label: I, Predicted label: I
# Sample 204: Actual label: I, Predicted label: D
# Sample 205: Actual label: I, Predicted label: I
# Sample 206: Actual label: I, Predicted label: D
# Sample 207: Actual label: I, Predicted label: I
# Sample 208: Actual label: I, Predicted label: I
# Sample 209: Actual label: I, Predicted label: D
# Sample 210: Actual label: I, Predicted label: I
# Sample 211: Actual label: I, Predicted label: D
# Sample 212: Actual label: I, Predicted label: I
# Sample 213: Actual label: I, Predicted label: I
# Sample 214: Actual label: I, Predicted label: I
# Sample 215: Actual label: I, Predicted label: I
# Sample 216: Actual label: I, Predicted label: I
# Sample 217: Actual label: I, Predicted label: I
# Sample 218: Actual label: I, Predicted label: I
# Sample 219: Actual label: I, Predicted label: D
# Sample 220: Actual label: K, Predicted label: D
# Sample 221: Actual label: K, Predicted label: K
# Sample 222: Actual label: K, Predicted label: K
# Sample 223: Actual label: K, Predicted label: K
# Sample 224: Actual label: K, Predicted label: K
# Sample 225: Actual label: K, Predicted label: K
# Sample 226: Actual label: K, Predicted label: K
# Sample 227: Actual label: K, Predicted label: K
# Sample 228: Actual label: K, Predicted label: K
# Sample 229: Actual label: K, Predicted label: K
# Sample 230: Actual label: K, Predicted label: K
# Sample 231: Actual label: K, Predicted label: A
# Sample 232: Actual label: K, Predicted label: K
# Sample 233: Actual label: K, Predicted label: K
# Sample 234: Actual label: K, Predicted label: K
# Sample 235: Actual label: K, Predicted label: K
# Sample 236: Actual label: K, Predicted label: K
# Sample 237: Actual label: K, Predicted label: K
# Sample 238: Actual label: K, Predicted label: K
# Sample 239: Actual label: K, Predicted label: K
# Sample 240: Actual label: K, Predicted label: K
# Sample 241: Actual label: K, Predicted label: K
# Sample 242: Actual label: K, Predicted label: K
# Sample 243: Actual label: K, Predicted label: K
# Sample 244: Actual label: K, Predicted label: K
# Sample 245: Actual label: K, Predicted label: K
# Sample 246: Actual label: K, Predicted label: K
# Sample 247: Actual label: K, Predicted label: K
# Sample 248: Actual label: K, Predicted label: K
# Sample 249: Actual label: K, Predicted label: K
# Sample 250: Actual label: K, Predicted label: K
# Sample 251: Actual label: K, Predicted label: K
# Sample 252: Actual label: K, Predicted label: K
# Sample 253: Actual label: K, Predicted label: K
# Sample 254: Actual label: K, Predicted label: K
# Sample 255: Actual label: K, Predicted label: K
# Sample 256: Actual label: K, Predicted label: K
# Sample 257: Actual label: K, Predicted label: K
# Sample 258: Actual label: K, Predicted label: K
# Sample 259: Actual label: K, Predicted label: K
# Sample 260: Actual label: K, Predicted label: K
# Sample 261: Actual label: K, Predicted label: K
# Sample 262: Actual label: K, Predicted label: K
# Sample 263: Actual label: K, Predicted label: K
# Sample 264: Actual label: K, Predicted label: K
# Sample 265: Actual label: K, Predicted label: K
# Sample 266: Actual label: K, Predicted label: K
# Sample 267: Actual label: K, Predicted label: K
# Sample 268: Actual label: K, Predicted label: K
# Sample 269: Actual label: K, Predicted label: K
# Sample 270: Actual label: N, Predicted label: N
# Sample 271: Actual label: N, Predicted label: N
# Sample 272: Actual label: N, Predicted label: N
# Sample 273: Actual label: N, Predicted label: N
# Sample 274: Actual label: N, Predicted label: N
# Sample 275: Actual label: N, Predicted label: N
# Sample 276: Actual label: N, Predicted label: N
# Sample 277: Actual label: N, Predicted label: N
# Sample 278: Actual label: N, Predicted label: N
# Sample 279: Actual label: N, Predicted label: N
# Sample 280: Actual label: N, Predicted label: N
# Sample 281: Actual label: N, Predicted label: N
# Sample 282: Actual label: N, Predicted label: N
# Sample 283: Actual label: N, Predicted label: N
# Sample 284: Actual label: N, Predicted label: S
# Sample 285: Actual label: N, Predicted label: N
# Sample 286: Actual label: N, Predicted label: N
# Sample 287: Actual label: N, Predicted label: N
# Sample 288: Actual label: N, Predicted label: S
# Sample 289: Actual label: N, Predicted label: N
# Sample 290: Actual label: N, Predicted label: N
# Sample 291: Actual label: N, Predicted label: N
# Sample 292: Actual label: N, Predicted label: N
# Sample 293: Actual label: N, Predicted label: W
# Sample 294: Actual label: N, Predicted label: W
# Sample 295: Actual label: N, Predicted label: N
# Sample 296: Actual label: N, Predicted label: N
# Sample 297: Actual label: N, Predicted label: N
# Sample 298: Actual label: N, Predicted label: N
# Sample 299: Actual label: N, Predicted label: D
# Sample 300: Actual label: N, Predicted label: N
# Sample 301: Actual label: N, Predicted label: N
# Sample 302: Actual label: N, Predicted label: N
# Sample 303: Actual label: N, Predicted label: N
# Sample 304: Actual label: N, Predicted label: N
# Sample 305: Actual label: N, Predicted label: D
# Sample 306: Actual label: N, Predicted label: N
# Sample 307: Actual label: N, Predicted label: N
# Sample 308: Actual label: N, Predicted label: N
# Sample 309: Actual label: N, Predicted label: D
# Sample 310: Actual label: N, Predicted label: N
# Sample 311: Actual label: N, Predicted label: S
# Sample 312: Actual label: N, Predicted label: N
# Sample 313: Actual label: N, Predicted label: N
# Sample 314: Actual label: N, Predicted label: N
# Sample 315: Actual label: N, Predicted label: N
# Sample 316: Actual label: N, Predicted label: N
# Sample 317: Actual label: N, Predicted label: N
# Sample 318: Actual label: N, Predicted label: N
# Sample 319: Actual label: N, Predicted label: D
# Sample 320: Actual label: N, Predicted label: I
# Sample 321: Actual label: N, Predicted label: N
# Sample 322: Actual label: N, Predicted label: N
# Sample 323: Actual label: N, Predicted label: N
# Sample 324: Actual label: N, Predicted label: D
# Sample 325: Actual label: N, Predicted label: N
# Sample 326: Actual label: N, Predicted label: N
# Sample 327: Actual label: N, Predicted label: N
# Sample 328: Actual label: N, Predicted label: N
# Sample 329: Actual label: N, Predicted label: W
# Sample 330: Actual label: N, Predicted label: N
# Sample 331: Actual label: N, Predicted label: N
# Sample 332: Actual label: N, Predicted label: N
# Sample 333: Actual label: N, Predicted label: N
# Sample 334: Actual label: N, Predicted label: N
# Sample 335: Actual label: N, Predicted label: N
# Sample 336: Actual label: N, Predicted label: K
# Sample 337: Actual label: N, Predicted label: N
# Sample 338: Actual label: N, Predicted label: N
# Sample 339: Actual label: N, Predicted label: N
# Sample 340: Actual label: N, Predicted label: I
# Sample 341: Actual label: N, Predicted label: N
# Sample 342: Actual label: N, Predicted label: N
# Sample 343: Actual label: N, Predicted label: N
# Sample 344: Actual label: N, Predicted label: N
# Sample 345: Actual label: N, Predicted label: N
# Sample 346: Actual label: N, Predicted label: N
# Sample 347: Actual label: N, Predicted label: I
# Sample 348: Actual label: N, Predicted label: N
# Sample 349: Actual label: N, Predicted label: N
# Sample 350: Actual label: N, Predicted label: N
# Sample 351: Actual label: N, Predicted label: N
# Sample 352: Actual label: N, Predicted label: N
# Sample 353: Actual label: N, Predicted label: N
# Sample 354: Actual label: N, Predicted label: N
# Sample 355: Actual label: N, Predicted label: S
# Sample 356: Actual label: N, Predicted label: N
# Sample 357: Actual label: N, Predicted label: N
# Sample 358: Actual label: N, Predicted label: N
# Sample 359: Actual label: N, Predicted label: N
# Sample 360: Actual label: S, Predicted label: S
# Sample 361: Actual label: S, Predicted label: N
# Sample 362: Actual label: S, Predicted label: N
# Sample 363: Actual label: S, Predicted label: S
# Sample 364: Actual label: S, Predicted label: I
# Sample 365: Actual label: S, Predicted label: S
# Sample 366: Actual label: S, Predicted label: S
# Sample 367: Actual label: S, Predicted label: I
# Sample 368: Actual label: S, Predicted label: I
# Sample 369: Actual label: S, Predicted label: D
# Sample 370: Actual label: S, Predicted label: S
# Sample 371: Actual label: S, Predicted label: N
# Sample 372: Actual label: S, Predicted label: N
# Sample 373: Actual label: S, Predicted label: S
# Sample 374: Actual label: S, Predicted label: A
# Sample 375: Actual label: S, Predicted label: N
# Sample 376: Actual label: S, Predicted label: S
# Sample 377: Actual label: S, Predicted label: N
# Sample 378: Actual label: S, Predicted label: N
# Sample 379: Actual label: S, Predicted label: N
# Sample 380: Actual label: S, Predicted label: N
# Sample 381: Actual label: S, Predicted label: N
# Sample 382: Actual label: S, Predicted label: N
# Sample 383: Actual label: S, Predicted label: N
# Sample 384: Actual label: S, Predicted label: N
# Sample 385: Actual label: S, Predicted label: S
# Sample 386: Actual label: S, Predicted label: S
# Sample 387: Actual label: S, Predicted label: S
# Sample 388: Actual label: S, Predicted label: S
# Sample 389: Actual label: S, Predicted label: S
# Sample 390: Actual label: S, Predicted label: S
# Sample 391: Actual label: S, Predicted label: I
# Sample 392: Actual label: S, Predicted label: N
# Sample 393: Actual label: S, Predicted label: I
# Sample 394: Actual label: S, Predicted label: S
# Sample 395: Actual label: S, Predicted label: S
# Sample 396: Actual label: S, Predicted label: S
# Sample 397: Actual label: S, Predicted label: S
# Sample 398: Actual label: S, Predicted label: S
# Sample 399: Actual label: S, Predicted label: A
# Sample 400: Actual label: S, Predicted label: S
# Sample 401: Actual label: S, Predicted label: S
# Sample 402: Actual label: S, Predicted label: S
# Sample 403: Actual label: S, Predicted label: D
# Sample 404: Actual label: S, Predicted label: I
# Sample 405: Actual label: S, Predicted label: S
# Sample 406: Actual label: S, Predicted label: S
# Sample 407: Actual label: S, Predicted label: S
# Sample 408: Actual label: S, Predicted label: S
# Sample 409: Actual label: S, Predicted label: S
# Sample 410: Actual label: S, Predicted label: S
# Sample 411: Actual label: S, Predicted label: S
# Sample 412: Actual label: S, Predicted label: S
# Sample 413: Actual label: S, Predicted label: N
# Sample 414: Actual label: S, Predicted label: N
# Sample 415: Actual label: S, Predicted label: N
# Sample 416: Actual label: S, Predicted label: N
# Sample 417: Actual label: S, Predicted label: S
# Sample 418: Actual label: S, Predicted label: N
# Sample 419: Actual label: S, Predicted label: S
# Sample 420: Actual label: S, Predicted label: D
# Sample 421: Actual label: S, Predicted label: D
# Sample 422: Actual label: S, Predicted label: D
# Sample 423: Actual label: S, Predicted label: S
# Sample 424: Actual label: S, Predicted label: S
# Sample 425: Actual label: S, Predicted label: S
# Sample 426: Actual label: S, Predicted label: S
# Sample 427: Actual label: S, Predicted label: S
# Sample 428: Actual label: S, Predicted label: S
# Sample 429: Actual label: S, Predicted label: S
# Sample 430: Actual label: W, Predicted label: W
# Sample 431: Actual label: W, Predicted label: N
# Sample 432: Actual label: W, Predicted label: W
# Sample 433: Actual label: W, Predicted label: W
# Sample 434: Actual label: W, Predicted label: W
# Sample 435: Actual label: W, Predicted label: W
# Sample 436: Actual label: W, Predicted label: W
# Sample 437: Actual label: W, Predicted label: W
# Sample 438: Actual label: W, Predicted label: W
# Sample 439: Actual label: W, Predicted label: W
# Sample 440: Actual label: W, Predicted label: W
# Sample 441: Actual label: W, Predicted label: W
# Sample 442: Actual label: W, Predicted label: W
# Sample 443: Actual label: W, Predicted label: W
# Sample 444: Actual label: W, Predicted label: W
# Sample 445: Actual label: W, Predicted label: W
# Sample 446: Actual label: W, Predicted label: W
# Sample 447: Actual label: W, Predicted label: W
# Sample 448: Actual label: W, Predicted label: W
# Sample 449: Actual label: W, Predicted label: A
# Sample 450: Actual label: W, Predicted label: N
# Sample 451: Actual label: W, Predicted label: W
# Sample 452: Actual label: W, Predicted label: N
# Sample 453: Actual label: W, Predicted label: W
# Sample 454: Actual label: W, Predicted label: W
# Sample 455: Actual label: W, Predicted label: N
# Sample 456: Actual label: W, Predicted label: N
# Sample 457: Actual label: W, Predicted label: A
# Sample 458: Actual label: W, Predicted label: A
# Sample 459: Actual label: W, Predicted label: W
# Sample 460: Actual label: W, Predicted label: W
# Sample 461: Actual label: W, Predicted label: W
# Sample 462: Actual label: W, Predicted label: W
# Sample 463: Actual label: W, Predicted label: W
# Sample 464: Actual label: W, Predicted label: W
# Sample 465: Actual label: W, Predicted label: W
# Sample 466: Actual label: W, Predicted label: W
# Sample 467: Actual label: W, Predicted label: W
# Sample 468: Actual label: W, Predicted label: W
# Sample 469: Actual label: W, Predicted label: W
# Sample 470: Actual label: W, Predicted label: A
# Sample 471: Actual label: W, Predicted label: W
# Sample 472: Actual label: W, Predicted label: W
# Sample 473: Actual label: W, Predicted label: N
# Sample 474: Actual label: W, Predicted label: A
# Sample 475: Actual label: W, Predicted label: W
# Sample 476: Actual label: W, Predicted label: W
# Sample 477: Actual label: W, Predicted label: D
# Sample 478: Actual label: W, Predicted label: W
# Sample 479: Actual label: W, Predicted label: D
# Sample 480: Actual label: W, Predicted label: A
# Sample 481: Actual label: W, Predicted label: A
# Sample 482: Actual label: W, Predicted label: W
# Sample 483: Actual label: W, Predicted label: W
# Sample 484: Actual label: W, Predicted label: W
# Sample 485: Actual label: W, Predicted label: A
# Sample 486: Actual label: W, Predicted label: W
# Sample 487: Actual label: W, Predicted label: W
# Sample 488: Actual label: W, Predicted label: W
# Sample 489: Actual label: W, Predicted label: W
# Accuracy: 77.96%
